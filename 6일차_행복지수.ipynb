# %% [markdown]
# # 시도/삶의만족도/건강/안전/환경/경제/교육/관계및사회참여/여가 컬럼으로

# %%
# %pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: openpyxl in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openpyxl) (2.0.0)

# %%
import pandas as pd

# %%
happy_life=pd.read_excel('happy\대한민국행복지도_삶의만족도.xlsx',engine='openpyxl')
happy_life.head()
# Out:
#    No     시도   구군  삶의 만족도
# 0   1  서울특별시  종로구  0.4437
# 1   2  서울특별시   중구  0.4976
# 2   3  서울특별시  용산구  0.6161
# 3   4  서울특별시  성동구  0.4729
# 4   5  서울특별시  광진구  0.4041

# %%
happy_merge=happy_life.groupby('시도')[['삶의 만족도']].mean()
happy_merge.head() # 이 옆의 여가... 주루룩 나오도록
# Out:
#          삶의 만족도
# 시도
# 강원도    0.619506
# 경기도    0.426023
# 경상남도   0.530794
# 경상북도   0.502223
# 광주광역시  0.484480

# %%
happy_health=pd.read_excel('happy\대한민국행복지도_건강.xlsx',engine='openpyxl')
happy_health.head()
# Out:
#    No     시도   구군      평균  주관적 건강수준 인지율  인구 십만명당 정신건강증진기관 수  \
# 0   1  서울특별시  종로구  0.9220        0.8424              0.6914
# 1   2  서울특별시   중구  0.6742        0.5772              0.4106
# 2   3  서울특별시  용산구  0.5898        0.9819              0.3353
# 3   4  서울특별시  성동구  0.4794        0.5465              0.3321
# 4   5  서울특별시  광진구  0.6373        0.8534              0.7393
#
#    인구 천명당 의료기관 종사 의사수  건강생활실천율  인구 천명당 의료기관병상수
# 0              1.0000   0.9697          0.7616
# 1              0.9995   0.9669          0.4043
# 2              0.6046   0.9844          0.1433
# 3              0.5783   0.9776          0.2111
# 4              0.6352   0.8022          0.1936

# %%
happy_safe=pd.read_excel('happy\대한민국행복지도_안전.xlsx',engine='openpyxl')
happy_safe.head()
# Out:
#    No     시도   구군      평균  사회안전에 대한 인식 b)  인구 천명당 cctv 대수 b)  \
# 0   1  서울특별시  종로구  0.7470          0.9965             0.4796
# 1   2  서울특별시   중구  0.9320          0.9707             0.8214
# 2   3  서울특별시  용산구  0.5537          0.6641             0.4311
# 3   4  서울특별시  성동구  0.5347          0.7452             0.4330
# 4   5  서울특별시  광진구  0.6072          0.7179             0.2196
#
#    인구 십만명당 응급의료기관 및 응급실 운영기관수  단위면적당 지역경찰관서 수  지역안전등급 현황 중 '교통사고 및 화재' a)
# 0                      0.7498          0.9998                      0.0162
# 1                      0.6938          1.0000                      0.3014
# 2                      0.1768          0.8923                      0.5075
# 3                      0.1562          0.9800                      0.3014
# 4                      0.2019          0.9785                      0.7117

# %%
happy_environ=pd.read_excel('happy\대한민국행복지도_환경.xlsx',engine='openpyxl')
happy_environ.head()
# Out:
#    No     시도   구군      평균  환경체감도 b)  인구 천명당 1일 산업폐수 방류량 a)  도시지역 중 '녹지지역 비율'  \
# 0   1  서울특별시  종로구  0.4637    0.4658                 0.7223            0.2012
# 1   2  서울특별시   중구  0.2865    0.1077                 0.6957            0.0013
# 2   3  서울특별시  용산구  0.5030    0.3142                 0.7185            0.1349
# 3   4  서울특별시  성동구  0.4196    0.1480                 0.6868            0.0347
# 4   5  서울특별시  광진구  0.4992    0.1229                 0.6940            0.0574
#
#    미세먼지(PM2.5) a) b)  주민 1인당 생활폐기물배출량 a)
# 0             0.7704              0.0006
# 1             0.6617              0.0000
# 2             0.6895              0.4571
# 3             0.3757              0.7426
# 4             0.7235              0.7016

# %%
happy_econo=pd.read_excel('happy\대한민국행복지도_경제.xlsx',engine='openpyxl')
happy_econo.head()
# Out:
#    No     시도   구군      평균  1인당 지역내총생산(GRDP)  인구 천명당 사업체수  인구 천명당 종사자수  \
# 0   1  서울특별시  종로구  1.0000            1.0000       1.0000       1.0000
# 1   2  서울특별시   중구  0.9806            1.0000       1.0000       1.0000
# 2   3  서울특별시  용산구  0.6915            0.6334       0.5493       0.7282
# 3   4  서울특별시  성동구  0.6533            0.5132       0.5368       0.6849
# 4   5  서울특별시  광진구  0.4445            0.2906       0.3424       0.3870
#
#    국민기초생활보장 수급자비율 a)  종사자 천명당 영세자영업자 수 a)
# 0             0.7564               0.9037
# 1             0.6718               0.9177
# 2             0.7910               0.8341
# 3             0.8243               0.8377
# 4             0.8681               0.7480

# %%
happy_edu=pd.read_excel('happy\대한민국행복지도_교육.xlsx',engine='openpyxl')
happy_edu.head()
# Out:
#    No     시도   구군      평균  교원 1인당 학생수  영유아 천명당 보육시설 수  인구 십만명당 학교수  \
# 0   1  서울특별시  종로구  0.6839      0.8505          0.6248       0.2249
# 1   2  서울특별시   중구  0.5013      0.8729          0.4147       0.2294
# 2   3  서울특별시  용산구  0.2679      0.6479          0.3804       0.1281
# 3   4  서울특별시  성동구  0.2464      0.7661          0.2270       0.1308
# 4   5  서울특별시  광진구  0.4879      0.9309          0.4263       0.1278
#
#    인구 천명당 사설학원수
# 0        0.8126
# 1        0.2944
# 2        0.1629
# 3        0.3366
# 4        0.4607

# %%
happy_relation=pd.read_excel('happy\대한민국행복지도_관계및사회참여.xlsx',engine='openpyxl')
happy_relation.head()
# Out:
#    No     시도   구군      평균  인구 십만명당 자살률 a)  1인가구(독거노인 제외) 비율 a)  독거노인가구 비율 a)  \
# 0   1  서울특별시  종로구  0.7425          0.8318               0.0057        0.7593
# 1   2  서울특별시   중구  0.4608          0.5462               0.0107        0.7254
# 2   3  서울특별시  용산구  0.4317          0.7288               0.0211        0.7754
# 3   4  서울특별시  성동구  0.4182          0.7288               0.0791        0.8332
# 4   5  서울특별시  광진구  0.3519          0.9434               0.0051        0.8541
#
#    인구 십만명당 사회적기업수  가족관계 만족도 b)
# 0          0.9981       0.5949
# 1          1.0000       0.2329
# 2          0.7194       0.2009
# 3          0.6783       0.0937
# 4          0.2461       0.2058

# %%
happy_leisure=pd.read_excel('happy\대한민국행복지도_관계및사회참여.xlsx',engine='openpyxl')
happy_leisure.head()
# Out:
#    No     시도   구군      평균  인구 십만명당 자살률 a)  1인가구(독거노인 제외) 비율 a)  독거노인가구 비율 a)  \
# 0   1  서울특별시  종로구  0.7425          0.8318               0.0057        0.7593
# 1   2  서울특별시   중구  0.4608          0.5462               0.0107        0.7254
# 2   3  서울특별시  용산구  0.4317          0.7288               0.0211        0.7754
# 3   4  서울특별시  성동구  0.4182          0.7288               0.0791        0.8332
# 4   5  서울특별시  광진구  0.3519          0.9434               0.0051        0.8541
#
#    인구 십만명당 사회적기업수  가족관계 만족도 b)
# 0          0.9981       0.5949
# 1          1.0000       0.2329
# 2          0.7194       0.2009
# 3          0.6783       0.0937
# 4          0.2461       0.2058

# %%
import os
path='happy/'
file_list=os.listdir(path)
file_list
# Out:
# ['대한민국행복지도_건강.xlsx',
#  '대한민국행복지도_경제.xlsx',
#  '대한민국행복지도_관계및사회참여.xlsx',
#  '대한민국행복지도_교육.xlsx',
#  '대한민국행복지도_삶의만족도.xlsx',
#  '대한민국행복지도_안전.xlsx',
#  '대한민국행복지도_여가.xlsx',
#  '대한민국행복지도_환경.xlsx']

# %%
keywords={'건강':'happy_health','안전':'happy_safe','환경':'happy_environ','경제':'happy_econo','교육':'happy_edu',
          '관계및사회참여':'happy_relation','여가':'happy_leisure'
}

try:
    for i in file_list:
        if i.endswith('.xlsx'):
            for x,y in keywords.items():
                if x in i:
                    keywords[x]=pd.read_excel(path+i,engine='openpyxl')
                    health=keywords[x].groupby('시도')[['평균']].mean()
                    happy_merge=pd.merge(happy_merge,health.rename(columns={'평균':x}),on='시도')
except:
    print(i)

# %%
# 미션: 어느 특정 시를 누르면 그 시만 가져와서 구군별 분석
